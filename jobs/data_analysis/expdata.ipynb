# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\brian\Desktop\JUNSOO\data_sP\Maple_exp.csv")

# %%
df

# %%
df.drop(columns = ["전 구간 대비 증가율","누적 경험치","열1","열2"] , inplace = True)
df["level"] = df["레벨 구간"].str.split().str[0]
df["need_exp"] = df["필요 경험치"]

# %%
df
# Out:
#         레벨 구간                 필요 경험치 level               need_exp
# 0   260 → 261      1,731,919,984,062   260      1,731,919,984,062
# 1   261 → 262      1,749,239,183,902   261      1,749,239,183,902
# 2   262 → 263      1,766,731,575,741   262      1,766,731,575,741
# 3   263 → 264      1,784,398,891,498   263      1,784,398,891,498
# 4   264 → 265      1,802,242,880,412   264      1,802,242,880,412
# 5   265 → 266      2,342,915,744,535   265      2,342,915,744,535
# 6   266 → 267      2,366,344,901,980   266      2,366,344,901,980
# 7   267 → 268      2,390,008,350,999   267      2,390,008,350,999
# 8   268 → 269      2,413,908,434,508   268      2,413,908,434,508
# 9   269 → 270      2,438,047,518,853   269      2,438,047,518,853
# 10  270 → 271      5,412,465,491,853   270      5,412,465,491,853
# 11  271 → 272      5,466,590,146,771   271      5,466,590,146,771
# 12  272 → 273      5,521,256,048,238   272      5,521,256,048,238
# ...

# %%
df = df[["level","need_exp"]]

# %%
df["need_exp"] = df["need_exp"].str.replace(",","")
df["need_exp"] = df["need_exp"].astype("int64")
df
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_5452\3849306613.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["need_exp"] = df["need_exp"].str.replace(",","")
# C:\Users\brian\AppData\Local\Temp\ipykernel_5452\3849306613.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["need_exp"] = df["need_exp"].astype("int64")
#    level          need_exp
# 0    260     1731919984062
# 1    261     1749239183902
# 2    262     1766731575741
# 3    263     1784398891498
# ...

# %%
df.to_csv(r"C:\Users\brian\Desktop\JUNSOO\Project\Game_domain\data\test_data\maple_exp.csv")

# %%
from datetime import datetime, timedelta

date = datetime.now().strftime("2024-%m-%d")
print(date)
# Out:
# 2024-08-18

# %%
date = (datetime.now() - timedelta(1)).strftime("2024-%m-%d")
print(date)
# Out:
# 2024-08-17
